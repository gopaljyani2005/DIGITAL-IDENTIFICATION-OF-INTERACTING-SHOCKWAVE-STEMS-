# %% [markdown]
# # ***google collab to connect drive***

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # ***import the library or python module***

# %%
import cv2
import os

# %% [markdown]
# # ***vidios to image convert ***
#
# # **1.   make is staic dataset**

# %%
def convert_video_to_images(video_path, output_folder):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Open the video file
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # Loop through each frame in the video
    for frame_number in range(total_frames):
        # Read the frame
        ret, frame = cap.read()
        if not ret:
            break

        # Save the frame as an image
        output_file = os.path.join(output_folder, f"frame_{frame_number}.jpg")
        cv2.imwrite(output_file, frame)

        print(f"Processed frame {frame_number + 1}/{total_frames}")

    # Release the VideoCapture object
    cap.release()
    print("Conversion completed.")

# %% [markdown]
# # import vidio and conver image **bold text** *bold text*

# %%
# Example usage
video_path = "/content/drive/MyDrive/fm_pjoject/3CYL_Flow.mp4"
output_folder = "/content/drive/MyDrive/fm_pjoject/image_of_project "
convert_video_to_images(video_path, output_folder)
# Out:
# Processed frame 1/751
# Processed frame 2/751
# Processed frame 3/751
# Processed frame 4/751
# Processed frame 5/751
# Processed frame 6/751
# Processed frame 7/751
# Processed frame 8/751
# Processed frame 9/751
# Processed frame 10/751
# Processed frame 11/751
# Processed frame 12/751
# Processed frame 13/751
# Processed frame 14/751
# Processed frame 15/751
# Processed frame 16/751
# Processed frame 17/751
# Processed frame 18/751
# Processed frame 19/751
# Processed frame 20/751
# Processed frame 21/751
# Processed frame 22/751
# Processed frame 23/751
# Processed frame 24/751
# Processed frame 25/751
# Processed frame 26/751
# Processed frame 27/751
# Processed frame 28/751
# Processed frame 29/751
# Processed frame 30/751
# Processed frame 31/751
# Processed frame 32/751
# Processed frame 33/751
# Processed frame 34/751
# Processed frame 35/751
# Processed frame 36/751
# Processed frame 37/751
# Processed frame 38/751
# Processed frame 39/751
# Processed frame 40/751
# ...

# %% [markdown]
# # ***image of this vidio dataset***

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the image
image = mpimg.imread("/content/drive/MyDrive/fm_pjoject/image_of_project /frame_101.jpg")

# Display the image
plt.imshow(image)
plt.axis('off')  # Hide axes
plt.show()
