# %% [markdown]
# # ***Mount Google Drive***

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from PIL import Image

# %% [markdown]
# # ***RGB to Black and White***

# %%
def rgb_to_bw_folder(input_folder, output_folder):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # List all files in the input folder
    files = os.listdir(input_folder)

    # Loop through each file in the input folder
    for file in files:
        # Check if the file is an image (JPEG or PNG)
        if file.lower().endswith(('.jpg', '.jpeg', '.png')):
            # Open the image
            image_path = os.path.join(input_folder, file)
            image = Image.open(image_path)

            # Convert the image to grayscale
            grayscale_image = image.convert("L")

            # Save the grayscale image to the output folder
            output_path = os.path.join(output_folder, file)
            grayscale_image.save(output_path)

# %% [markdown]
# # ***Load The Data***

# %%
input_folder = "/content/drive/MyDrive/fm_pjoject/image_of_project "
output_folder = "/content/drive/MyDrive/fm_pjoject/image_2"

# %% [markdown]
# # ***Convert all images in the input folder to grayscale***

# %%
# Convert all images in the input folder to grayscale and save them in the output folder
rgb_to_bw_folder(input_folder, output_folder)
